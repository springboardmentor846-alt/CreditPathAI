# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("../data/loan_sample.csv")

# Basic info
df.head()

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\kohin\\GitHub\\CreditPathAi'

# %%
df = pd.read_csv("data/loan_sample.csv")
df.head()
# Out:
#    loan_id  loan_amount  term  interest_rate  annual_income  delinquent_2yrs  \
# 0        1         5000    36           13.5          35000                0
# 1        2        15000    60           18.9          45000                1
# 2        3        12000    36           11.2          52000                0
# 3        4        20000    60           20.5          40000                2
#
#    open_accounts  past_due  loan_status
# 0              5         0   fully_paid
# 1              8         1  charged_off
# 2              6         0   fully_paid
# 3             10         1  charged_off

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.13.2'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

# %%
df = pd.read_csv("data/loan_sample.csv")
df.head()
# Out:
#    loan_id  loan_amount  term  interest_rate  annual_income  delinquent_2yrs  \
# 0        1         5000    36           13.5          35000                0
# 1        2        15000    60           18.9          45000                1
# 2        3        12000    36           11.2          52000                0
# 3        4        20000    60           20.5          40000                2
#
#    open_accounts  past_due  loan_status
# 0              5         0   fully_paid
# 1              8         1  charged_off
# 2              6         0   fully_paid
# 3             10         1  charged_off

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   loan_id          4 non-null      int64
#  1   loan_amount      4 non-null      int64
#  2   term             4 non-null      int64
#  3   interest_rate    4 non-null      float64
#  4   annual_income    4 non-null      int64
#  5   delinquent_2yrs  4 non-null      int64
#  6   open_accounts    4 non-null      int64
#  7   past_due         4 non-null      int64
#  8   loan_status      4 non-null      object
# dtypes: float64(1), int64(7), object(1)
# memory usage: 420.0+ bytes
#         loan_id   loan_amount       term  interest_rate  annual_income  \
# count  4.000000      4.000000   4.000000       4.000000       4.000000
# mean   2.500000  13000.000000  48.000000      16.025000   43000.000000
# std    1.290994   6271.629241  13.856406       4.394978    7257.180352
# min    1.000000   5000.000000  36.000000      11.200000   35000.000000
# 25%    1.750000  10250.000000  36.000000      12.925000   38750.000000
# 50%    2.500000  13500.000000  48.000000      16.200000   42500.000000
# 75%    3.250000  16250.000000  60.000000      19.300000   46750.000000
# max    4.000000  20000.000000  60.000000      20.500000   52000.000000
#
#        delinquent_2yrs  open_accounts  past_due
# count         4.000000       4.000000   4.00000
# mean          0.750000       7.250000   0.50000
# std           0.957427       2.217356   0.57735
# min           0.000000       5.000000   0.00000
# 25%           0.000000       5.750000   0.00000
# 50%           0.500000       7.000000   0.50000
# 75%           1.250000       8.500000   1.00000
# max           2.000000      10.000000   1.00000

# %%
df.isnull().sum()
# Out:
# loan_id            0
# loan_amount        0
# term               0
# interest_rate      0
# annual_income      0
# delinquent_2yrs    0
# open_accounts      0
# past_due           0
# loan_status        0
# dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["loan_amount"], kde=True)
plt.title("Loan Amount Distribution")
# Out:
# Text(0.5, 1.0, 'Loan Amount Distribution')

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df["loan_status"], y=df["interest_rate"])
plt.title("Interest Rate vs Loan Status")
# Out:
# Text(0.5, 1.0, 'Interest Rate vs Loan Status')

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])
plt.figure(figsize=(8,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap (Numeric Only)")
plt.show()

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\kohin\\GitHub\\CreditPathAi'
